# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
election_datafile = "2020_data.csv"
covid_datafile = "covid-19-data/us-counties-recent.csv"
pop_datafile = "co-est2020.csv"
#felec = open(election_datafile,'r')
#fcov = open(covid_datafile)

# %%
class county():
    def __init__(self,name,pop):
        self.name=name
        self.pop=pop

class county_dict():
    def __init__(self,pop_datafile):
        f = open(pop_datafile,encoding="ISO-8859-1")
        headers = f.readline()
        headers = headers.split(',')
        self.county_list = []
        self.popfile_headers=headers
      
        for line in f.readlines():
            county_data = line.split(',')
            self.county_list.append(county_data)

# %%
myCounties = county_dict(pop_datafile)
myCounties.county_list[1]
# Out:
# ['050',
#  '3',
#  '6',
#  '01',
#  '001',
#  'Alabama',
#  'Autauga County',
#  '54571',
#  '54582',
#  '54761',
#  '55229',
#  '54970',
#  '54747',
#  '54922',
#  '54903',
#  '55302',
#  '55448',
#  '55533',
#  '55769',
#  '56130',
#  '56145\n']

# %%
covid_df = pd.read_csv(covid_datafile)
election_df = pd.read_csv(election_datafile)
pop_df = pd.read_csv(pop_datafile,encoding="ISO-8859-1")

# %%
election_df
# Out:
#      state_name  county_fips        county_name  votes_gop  votes_dem  \
# 0       Alabama         1001     Autauga County      19838       7503
# 1       Alabama         1003     Baldwin County      83544      24578
# 2       Alabama         1005     Barbour County       5622       4816
# 3       Alabama         1007        Bibb County       7525       1986
# 4       Alabama         1009      Blount County      24711       2640
# ...         ...          ...                ...        ...        ...
# 3147    Wyoming        56037  Sweetwater County      12229       3823
# 3148    Wyoming        56039       Teton County       4341       9848
# 3149    Wyoming        56041       Uinta County       7496       1591
# 3150    Wyoming        56043    Washakie County       3245        651
# 3151    Wyoming        56045      Weston County       3107        360
#
#       total_votes   diff   per_gop   per_dem  per_point_diff
# 0           27770  12335  0.714368  0.270184        0.444184
# ...
